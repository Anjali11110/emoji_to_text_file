# %%
# !pip install demoji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 1.6 MB/s eta 0:00:00
# ...

# %%
import demoji
emoji="😀😃🥰😘😘😕"
text=demoji.findall(emoji)
print(text)
# Out:
# {'😃': 'grinning face with big eyes', '🥰': 'smiling face with hearts', '😀': 'grinning face', '😘': 'face blowing a kiss', '😕': 'confused face'}

# %%
import json

# text = {"key1": "value1", "key2": "value2"}

with open("text.txt", "w+") as f:
    json.dump(text, f)

# with open("text.txt","w+") as f:
#     f.write(text)
